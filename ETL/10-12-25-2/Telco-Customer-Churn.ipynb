# %%
import pandas as pd
from supabase import create_client
import os
from dotenv import load_dotenv

# ---------------------------------------
# Load environment variables
# ---------------------------------------
load_dotenv()

# ---------------------------------------
# Supabase client setup
# ---------------------------------------
SUPABASE_URL = os.getenv("SUPABASE_URL")
SUPABASE_KEY = os.getenv("SUPABASE_KEY")
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

# ---------------------------------------
# Read data from Supabase table
# ---------------------------------------
data = supabase.table("telco_data").select("*").execute()

# Convert to DataFrame
df = pd.DataFrame(data.data)

# ---------------------------------------
# Inspect dataframe
# ---------------------------------------

# Head of the dataset
display(df.head())

# Data types and non-null info
print("\n--- INFO ---")
display(df.info())

# Count missing values
print("\n--- Missing Values ---")
display(df.isnull().sum())

# Describe statistics
print("\n--- Describe ---")
display(df.describe(include="all"))

# Column names
print("\n--- Columns ---")
display(df.columns)
# Out:
#    id  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0   1  Female              0     Yes         No       1           No
# 1   2    Male              0      No         No      34          Yes
# 2   3    Male              0      No         No       2          Yes
# 3   4    Male              0      No         No      45           No
# 4   5  Female              0      No         No       2          Yes
#
#   internetservice onlinesecurity onlinebackup  ... paperlessbilling  \
# 0             DSL             No          Yes  ...              Yes
# 1             DSL            Yes           No  ...               No
# 2             DSL            Yes          Yes  ...              Yes
# 3             DSL            Yes           No  ...               No
# 4     Fiber optic             No           No  ...              Yes
#
#                paymentmethod monthlycharges totalcharges churn tenure_group  \
# 0           Electronic check          29.85        29.85     0         0-12
# 1               Mailed check          56.95      1889.50     0        24-48
# 2               Mailed check          53.85       108.15     1         0-12
# 3  Bank transfer (automatic)          42.30      1840.75     0        24-48
# 4           Electronic check          70.70       151.65     1         0-12
#
#   monthlycharges_group  total_services  customerid     multiplelines
# 0                  Low               0        None  No phone service
# 1               Medium               0        None                No
# 2               Medium               0        None                No
# 3               Medium               0        None  No phone service
# 4                 High               0        None                No
#
# [5 rows x 25 columns]
# --- INFO ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1000 non-null   int64
#  1   gender                1000 non-null   object
#  2   seniorcitizen         1000 non-null   int64
#  3   partner               1000 non-null   object
#  4   dependents            1000 non-null   object
#  5   tenure                1000 non-null   int64
#  6   phoneservice          1000 non-null   object
#  7   internetservice       1000 non-null   object
#  8   onlinesecurity        1000 non-null   object
#  9   onlinebackup          1000 non-null   object
#  10  deviceprotection      1000 non-null   object
#  11  techsupport           1000 non-null   object
#  12  streamingtv           1000 non-null   object
#  13  streamingmovies       1000 non-null   object
#  14  contract              1000 non-null   object
#  15  paperlessbilling      1000 non-null   object
#  16  paymentmethod         1000 non-null   object
#  17  monthlycharges        1000 non-null   float64
#  18  totalcharges          1000 non-null   float64
#  19  churn                 1000 non-null   int64
#  20  tenure_group          1000 non-null   object
#  21  monthlycharges_group  1000 non-null   object
#  22  total_services        1000 non-null   int64
#  23  customerid            0 non-null      object
#  24  multiplelines         1000 non-null   object
# dtypes: float64(2), int64(5), object(18)
# memory usage: 195.4+ KB
# None
# --- Missing Values ---
# id                         0
# gender                     0
# seniorcitizen              0
# partner                    0
# dependents                 0
# tenure                     0
# phoneservice               0
# internetservice            0
# onlinesecurity             0
# onlinebackup               0
# deviceprotection           0
# techsupport                0
# streamingtv                0
# streamingmovies            0
# contract                   0
# paperlessbilling           0
# paymentmethod              0
# monthlycharges             0
# totalcharges               0
# churn                      0
# tenure_group               0
# monthlycharges_group       0
# total_services             0
# customerid              1000
# multiplelines              0
# dtype: int64
# --- Describe ---
#                 id  gender  seniorcitizen partner dependents       tenure  \
# count   1000.00000    1000    1000.000000    1000       1000  1000.000000
# unique         NaN       2            NaN       2          2          NaN
# top            NaN  Female            NaN      No         No          NaN
# freq           NaN     516            NaN     516        688          NaN
# mean     503.70200     NaN       0.168000     NaN        NaN    31.492000
# std      311.24182     NaN       0.374053     NaN        NaN    24.402529
# min        1.00000     NaN       0.000000     NaN        NaN     0.000000
# 25%      250.75000     NaN       0.000000     NaN        NaN     8.000000
# 50%      500.50000     NaN       0.000000     NaN        NaN    28.000000
# 75%      750.25000     NaN       0.000000     NaN        NaN    52.250000
# max     4202.00000     NaN       1.000000     NaN        NaN    72.000000
#
#        phoneservice internetservice onlinesecurity onlinebackup  ...  \
# count          1000            1000           1000         1000  ...
# unique            2               3              3            3  ...
# top             Yes     Fiber optic             No           No  ...
# freq            890             453            523          424  ...
# mean            NaN             NaN            NaN          NaN  ...
# std             NaN             NaN            NaN          NaN  ...
# min             NaN             NaN            NaN          NaN  ...
# 25%             NaN             NaN            NaN          NaN  ...
# 50%             NaN             NaN            NaN          NaN  ...
# 75%             NaN             NaN            NaN          NaN  ...
# max             NaN             NaN            NaN          NaN  ...
#
#        paperlessbilling     paymentmethod monthlycharges totalcharges  \
# count              1000              1000     1000.00000  1000.000000
# unique                2                 4            NaN          NaN
# top                 Yes  Electronic check            NaN          NaN
# freq                602               336            NaN          NaN
# mean                NaN               NaN       65.95380  2224.548000
# std                 NaN               NaN       29.52356  2196.281707
# min                 NaN               NaN       18.95000    19.150000
# 25%                 NaN               NaN       44.22500   421.700000
# 50%                 NaN               NaN       71.52500  1373.050000
# 75%                 NaN               NaN       89.90000  3582.400000
# max                 NaN               NaN      116.05000  8468.200000
#
#               churn tenure_group monthlycharges_group  total_services  \
# count   1000.000000         1000                 1000          1000.0
# unique          NaN            4                    3             NaN
# top             NaN         0-12                 High             NaN
# freq            NaN          315                  520             NaN
# mean       0.255000          NaN                  NaN             0.0
# std        0.436079          NaN                  NaN             0.0
# min        0.000000          NaN                  NaN             0.0
# 25%        0.000000          NaN                  NaN             0.0
# 50%        0.000000          NaN                  NaN             0.0
# 75%        1.000000          NaN                  NaN             0.0
# max        1.000000          NaN                  NaN             0.0
#
#         customerid  multiplelines
# count            0           1000
# unique           0              3
# top            NaN             No
# freq           NaN            494
# mean           NaN            NaN
# std            NaN            NaN
# min            NaN            NaN
# 25%            NaN            NaN
# 50%            NaN            NaN
# 75%            NaN            NaN
# max            NaN            NaN
#
# [11 rows x 25 columns]
# --- Columns ---
# Index(['id', 'gender', 'seniorcitizen', 'partner', 'dependents', 'tenure',
#        'phoneservice', 'internetservice', 'onlinesecurity', 'onlinebackup',
#        'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies',
#        'contract', 'paperlessbilling', 'paymentmethod', 'monthlycharges',
#        'totalcharges', 'churn', 'tenure_group', 'monthlycharges_group',
#        'total_services', 'customerid', 'multiplelines'],
#       dtype='object')
